# %% [markdown]
# ## Anggraeni Bakti Setianingrum
#
# ## 200601110075
#
# # Rangkuman Pandas
#
# -------------------------------------------------------------------------------------

# %% [markdown]
# ## Instalasi

# %%
! pip install pandas

# %% [markdown]
# ## Series Object

# %%
import pandas as pd
data1 = [33, 19, 15, 89, 11, -5, 9]
index1 = ['Sen', 'Sel', 'Rab', 'Kam', 'Jum', 'Sab', 'Min']
s1 = pd.Series(data1, index=index1)
s1
# Out:
# Sen    33
# Sel    19
# Rab    15
# Kam    89
# Jum    11
# Sab    -5
# Min     9
# dtype: int64

# %%
s1.index
# Out:
# Index(['Sen', 'Sel', 'Rab', 'Kam', 'Jum', 'Sab', 'Min'], dtype='object')

# %%
s1.name = 'Suhu Harian'
s1.index.name = 'Hari'
s1
# Out:
# Hari
# Sen    33
# Sel    19
# Rab    15
# Kam    89
# Jum    11
# Sab    -5
# Min     9
# Name: Suhu Harian, dtype: int64

# %% [markdown]
# ## Operasi Vektor pada objek Series

# %%
s1 * 2
# Out:
# Hari
# Sen     66
# Sel     38
# Rab     30
# Kam    178
# Jum     22
# Sab    -10
# Min     18
# Name: Suhu Harian, dtype: int64

# %% [markdown]
# Karena data yang kita miliki berbentuk array, maka kita dapat melakukan operasi pembelahan (slicing) seperti halnya tipe data list dalam Python:

# %%
s1[1:4]
# Out:
# Hari
# Sel    19
# Rab    15
# Kam    89
# Name: Suhu Harian, dtype: int64

# %% [markdown]
# Begitu juga dengan operasi pengambilan (get) nilai menggunakan oﬀset

# %%
s1[3]
# Out:
# 89

# %% [markdown]
# Karena objek Series merupakan subclass dari ndarray, maka kita dapat menerapkan fungsi NumPy yang berkaitan dengannya, contoh

# %%
s1.median()
# Out:
# 15.0

# %%
s1.max()
# Out:
# 89

# %%
s1.cumsum()
# Out:
# Hari
# Sen     33
# Sel     52
# Rab     67
# Kam    156
# Jum    167
# Sab    162
# Min    171
# Name: Suhu Harian, dtype: int64

# %% [markdown]
# ## Looping Series

# %%
newlist = [x ** 2 for x in s1]
newlist
# Out:
# [1089, 361, 225, 7921, 121, 25, 81]

# %% [markdown]
# ## Membuat Objek DataFrame

# %%
import pandas as pd
from pylab import randint
temps = randint(100, size=(12, 4))
temps
# Out:
# array([[ 3, 69, 65, 81],
#        [55, 75, 82, 43],
#        [92, 55, 83, 24],
#        [47, 85, 48, 78],
#        [ 9, 22,  4, 93],
#        [ 7, 32,  0,  1],
#        [40, 68, 87, 40],
#        [ 4, 92,  5, 21],
#        [43, 31, 82, 57],
#        [53,  4, 27, 51],
#        [77, 55, 20, 17],
#        [48, 48, 83, 90]])

# %%
df1 = pd.DataFrame(temps)
df1
# Out:
#      0   1   2   3
# 0    3  69  65  81
# 1   55  75  82  43
# 2   92  55  83  24
# 3   47  85  48  78
# 4    9  22   4  93
# 5    7  32   0   1
# 6   40  68  87  40
# 7    4  92   5  21
# 8   43  31  82  57
# 9   53   4  27  51
# 10  77  55  20  17
# 11  48  48  83  90

# %% [markdown]
# ##  Membuat DataFrame dari berkas CSV

# %%
dataa = pd.read_csv('coba.txt')
dataa
# Out:
#    A B
# 0  1 2
# 1  4 3
# 2  4 2

# %% [markdown]
# ## Memberi Label pada baris dan kolom

# %%
rowlabels = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'] 
columnlabels = ['Denver', 'Austin', 'Boston', 'Atlanta'] 
df2 = pd.DataFrame(temps, index=rowlabels)
df3 = pd.DataFrame(temps, columns=columnlabels)
df4 = pd.DataFrame(temps, index=rowlabels, columns=columnlabels) 
df1
# Out:
#      0   1   2   3
# 0    3  69  65  81
# 1   55  75  82  43
# 2   92  55  83  24
# 3   47  85  48  78
# 4    9  22   4  93
# 5    7  32   0   1
# 6   40  68  87  40
# 7    4  92   5  21
# 8   43  31  82  57
# 9   53   4  27  51
# 10  77  55  20  17
# 11  48  48  83  90

# %%
df2
# Out:
#       0   1   2   3
# Jan   3  69  65  81
# Feb  55  75  82  43
# Mar  92  55  83  24
# Apr  47  85  48  78
# May   9  22   4  93
# Jun   7  32   0   1
# Jul  40  68  87  40
# Aug   4  92   5  21
# Sep  43  31  82  57
# Oct  53   4  27  51
# Nov  77  55  20  17
# Dec  48  48  83  90

# %%
df3
# Out:
#     Denver  Austin  Boston  Atlanta
# 0        3      69      65       81
# 1       55      75      82       43
# 2       92      55      83       24
# 3       47      85      48       78
# 4        9      22       4       93
# 5        7      32       0        1
# 6       40      68      87       40
# 7        4      92       5       21
# 8       43      31      82       57
# 9       53       4      27       51
# 10      77      55      20       17
# 11      48      48      83       90

# %%
df4
# Out:
#      Denver  Austin  Boston  Atlanta
# Jan       3      69      65       81
# Feb      55      75      82       43
# Mar      92      55      83       24
# Apr      47      85      48       78
# May       9      22       4       93
# Jun       7      32       0        1
# Jul      40      68      87       40
# Aug       4      92       5       21
# Sep      43      31      82       57
# Oct      53       4      27       51
# Nov      77      55      20       17
# Dec      48      48      83       90

# %% [markdown]
# Terlihat bahwa pada df1 kita belum memberi label pada DataFrame, pada df2, kita memberi label pada baris. df3 kita memberi label pada kolom, dan pada df4 kita memberikan label baik pada baris maupun kolom.

# %% [markdown]
# ## Subset of Rows

# %%
df1[5:7]
# Out:
#     0   1   2   3
# 5   7  32   0   1
# 6  40  68  87  40

# %%
df2['Feb': 'May']
# Out:
#       0   1   2   3
# Feb  55  75  82  43
# Mar  92  55  83  24
# Apr  47  85  48  78
# May   9  22   4  93

# %% [markdown]
# ## Subset of Rows

# %%
df3[['Denver']]
# Out:
#     Denver
# 0        3
# 1       55
# 2       92
# 3       47
# 4        9
# 5        7
# 6       40
# 7        4
# 8       43
# 9       53
# 10      77
# 11      48

# %%
df3[['Denver', 'Boston']]
# Out:
#     Denver  Boston
# 0        3      65
# 1       55      82
# 2       92      83
# 3       47      48
# 4        9       4
# 5        7       0
# 6       40      87
# 7        4       5
# 8       43      82
# 9       53      27
# 10      77      20
# 11      48      83

# %%
df3.Denver
# Out:
# 0      3
# 1     55
# 2     92
# 3     47
# 4      9
# 5      7
# 6     40
# 7      4
# 8     43
# 9     53
# 10    77
# 11    48
# Name: Denver, dtype: int64

# %% [markdown]
# ## Data Selection

# %%
import pandas as pd
from random import randrange
import numpy as np
from numpy import reshape
import matplotlib.pyplot as plt
np.array([randrange(0, 100) for i in range(42)]).reshape(7, 6)
# Out:
# array([[16, 54, 73, 65, 73, 93],
#        [43, 33, 21, 62, 97, 21],
#        [62, 11, 67, 25, 23, 75],
#        [65, 94, 50, 90, 37, 63],
#        [25, 51, 45,  0, 39, 53],
#        [14, 34, 30, 32,  1, 61],
#        [53,  5, 36, 16, 52,  0]])

# %%
rowids = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
colids = ['Boston', 'London', 'Paris', 'Sydney', 'Tokyo', 'Toronto']

# %%
t = np.array([randrange(0, 100) for i in range(42)]).reshape(7, 6)
t
# Out:
# array([[84, 38, 23, 89, 73, 58],
#        [61, 76, 67, 53, 29, 54],
#        [83, 95, 53, 98, 31, 80],
#        [19, 63, 35, 65, 31, 87],
#        [18, 95,  0, 53, 88, 40],
#        [90, 87, 98, 32, 27, 52],
#        [24,  9, 53, 96, 86, 23]])

# %%
temps = pd.DataFrame(t, index=rowids, columns=colids)
temps
# Out:
#      Boston  London  Paris  Sydney  Tokyo  Toronto
# Mon      84      38     23      89     73       58
# Tue      61      76     67      53     29       54
# Wed      83      95     53      98     31       80
# Thu      19      63     35      65     31       87
# Fri      18      95      0      53     88       40
# Sat      90      87     98      32     27       52
# Sun      24       9     53      96     86       23

# %%
 temps.Sydney >= 60
# Out:
# Mon     True
# Tue    False
# Wed     True
# Thu     True
# Fri    False
# Sat    False
# Sun     True
# Name: Sydney, dtype: bool

# %%
 temps[temps.Sydney >= 60]
# Out:
#      Boston  London  Paris  Sydney  Tokyo  Toronto
# Mon      84      38     23      89     73       58
# Wed      83      95     53      98     31       80
# Thu      19      63     35      65     31       87
# Sun      24       9     53      96     86       23

# %%
 mask = temps.Sydney >= 60
 temps[mask]
# Out:
#      Boston  London  Paris  Sydney  Tokyo  Toronto
# Mon      84      38     23      89     73       58
# Wed      83      95     53      98     31       80
# Thu      19      63     35      65     31       87
# Sun      24       9     53      96     86       23

# %%
mask1 = (temps.Sydney >= 60) & (temps.Toronto >= 60)
mask1
# Out:
# Mon    False
# Tue    False
# Wed     True
# Thu     True
# Fri    False
# Sat    False
# Sun    False
# dtype: bool

# %%
temps[mask1]
# Out:
#      Boston  London  Paris  Sydney  Tokyo  Toronto
# Wed      83      95     53      98     31       80
# Thu      19      63     35      65     31       87

# %% [markdown]
# Contoh lain lagi dari proses data selection: Misal kita ingin membuat linearly spaced array mulai angka -2*PI sampai 2*PI.

# %%
import numpy as np
x = np.linspace(-2*np.pi, 2*np.pi, 100)
y = np.sin(x**2)
import matplotlib.pyplot as plt
plt.plot(x, y) 
plt.show()

# %%
mask = y>=0
plt.plot(x, y) 
plt.plot(x[mask], y[mask], 's') 
plt.show()

# %% [markdown]
# ## Index Object

# %%
 import pandas as pd
 import numpy as np
 from pandas import Series, DataFrame
 obj = Series(range(3), index=['a', 'b', 'c'])
 index = obj.index 
 index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
index[1:]
# Out:
# Index(['b', 'c'], dtype='object')

# %% [markdown]
# Sifat immutable ini penting supaya index nilainya tetap terjaga ketika digunakan antar tipe data

# %%
index = pd.Index(np.arange(3))
index
# Out:
# Int64Index([0, 1, 2], dtype='int64')

# %%
obj2 = Series([1.5, -2.5, 0], index=index)
obj2.index is index
# Out:
# True

# %% [markdown]
# ## Dasar Plot

# %%
from numpy import linspace
x = linspace(-10, 10, 100)
y = 3 * x + 9
plt.plot(x, y)
plt.show()

# %%
y = 3*x**3 + 9
plt.plot(x, y)
plt.show()

# %% [markdown]
# Contoh selanjutnya menggambar plot untuk fungsi trigonometry:

# %%
from numpy import pi
from numpy import sin
from numpy import cos
x = linspace(-2*pi, 2*pi, 200)
y1 = sin(x)
y2 = cos(x)
plt.plot(x, y1) 
plt.plot(x, y2) 
plt.show()

# %% [markdown]
# ## Menyunting Properti Plot

# %%
plt.plot(x, y1, 'r') 
plt.plot(x, y2, 'g') 
plt.grid() 
plt.xlim(-2*pi, 2*pi) 
plt.ylim(-1.1, 1.1)
plt.show()

# %% [markdown]
# ## Memberi Label pada Plot

# %%
plt.plot(x, y1, 'r') 
plt.plot(x, y2, 'g')
plt.grid() 
plt.xlim(-2*pi, 2*pi) 
plt.ylim(-1.1, 1.1)
plt.xlabel('x') 
plt.ylabel('sin and cos functions') 
plt.title('A plot of sin and cos functions') 
plt.show()

# %% [markdown]
# ## Menggunakan Syntax Latex pada Plot

# %%
 x = linspace(-2*pi, 2*pi, 200) 
 y1 = sin(x**3) 
 plt.plot(x, y1, 'r') 
 plt.grid() 
 plt.xlim(-2*pi, 2*pi)  
 plt.ylim(-1.1, 1.1)
 plt.xlabel('x')  
 plt.ylabel('$y = sin(x^3)$') # <= syntax latex 
 plt.title('A plot of a trig function') 
 plt.show()

# %% [markdown]
# ## Menyimpan Plot

# %%
from matplotlib.pyplot import savefig 
savefig('gambar_1.png')

# %% [markdown]
# # Contoh Kasus
#
# ## Baby Names Data

# %%
import pandas as pd
import pylab
names = pd.read_csv('baby-names.csv')
names
# Out:
#         year      name   percent   sex
# 0       1880      John  0.081541   boy
# 1       1880   William  0.080511   boy
# 2       1880     James  0.050057   boy
# 3       1880   Charles  0.045167   boy
# 4       1880    George  0.043292   boy
# ...      ...       ...       ...   ...
# 257995  2008  Carleigh  0.000128  girl
# 257996  2008     Iyana  0.000128  girl
# 257997  2008    Kenley  0.000127  girl
# 257998  2008    Sloane  0.000127  girl
# 257999  2008   Elianna  0.000127  girl
#
# [258000 rows x 4 columns]

# %%
names.head()
# Out:
#    year     name   percent  sex
# 0  1880     John  0.081541  boy
# 1  1880  William  0.080511  boy
# 2  1880    James  0.050057  boy
# 3  1880  Charles  0.045167  boy
# 4  1880   George  0.043292  boy

# %%
names.head(12)
# Out:
#     year     name   percent  sex
# 0   1880     John  0.081541  boy
# 1   1880  William  0.080511  boy
# 2   1880    James  0.050057  boy
# 3   1880  Charles  0.045167  boy
# 4   1880   George  0.043292  boy
# 5   1880    Frank  0.027380  boy
# 6   1880   Joseph  0.022229  boy
# 7   1880   Thomas  0.021401  boy
# 8   1880    Henry  0.020641  boy
# 9   1880   Robert  0.020404  boy
# 10  1880   Edward  0.019965  boy
# 11  1880    Harry  0.018175  boy

# %% [markdown]
# jika ingin lebih ﬂeksibel, bisa menggunakan fungsi slicing

# %%
names[3:9]
# Out:
#    year     name   percent  sex
# 3  1880  Charles  0.045167  boy
# 4  1880   George  0.043292  boy
# 5  1880    Frank  0.027380  boy
# 6  1880   Joseph  0.022229  boy
# 7  1880   Thomas  0.021401  boy
# 8  1880    Henry  0.020641  boy

# %% [markdown]
# Modul Pandas memungkinkan kita membuat datasets baru dengan sangat mudah. Misal kita ingin membuat datasets nama bayi laki-laki saja atau perempuan saja.

# %%
names['sex'] == 'girl'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 257995     True
# 257996     True
# 257997     True
# 257998     True
# 257999     True
# Name: sex, Length: 258000, dtype: bool

# %%
girl_names = names[names['sex'] == 'girl'] 
boy_names = names[names['sex'] == 'boy']
girl_names
# Out:
#         year       name   percent   sex
# 129000  1880       Mary  0.072381  girl
# 129001  1880       Anna  0.026678  girl
# 129002  1880       Emma  0.020521  girl
# 129003  1880  Elizabeth  0.019865  girl
# 129004  1880     Minnie  0.017888  girl
# ...      ...        ...       ...   ...
# 257995  2008   Carleigh  0.000128  girl
# 257996  2008      Iyana  0.000128  girl
# 257997  2008     Kenley  0.000127  girl
# 257998  2008     Sloane  0.000127  girl
# 257999  2008    Elianna  0.000127  girl
#
# [129000 rows x 4 columns]

# %%
girl_names.head()
# Out:
#         year       name   percent   sex
# 129000  1880       Mary  0.072381  girl
# 129001  1880       Anna  0.026678  girl
# 129002  1880       Emma  0.020521  girl
# 129003  1880  Elizabeth  0.019865  girl
# 129004  1880     Minnie  0.017888  girl

# %%
boy_names
# Out:
#         year     name   percent  sex
# 0       1880     John  0.081541  boy
# 1       1880  William  0.080511  boy
# 2       1880    James  0.050057  boy
# 3       1880  Charles  0.045167  boy
# 4       1880   George  0.043292  boy
# ...      ...      ...       ...  ...
# 128995  2008   Kolten  0.000090  boy
# 128996  2008   Damari  0.000089  boy
# 128997  2008     Hugh  0.000089  boy
# 128998  2008   Jensen  0.000089  boy
# 128999  2008    Yurem  0.000089  boy
#
# [129000 rows x 4 columns]

# %%
boy_names.head()
# Out:
#    year     name   percent  sex
# 0  1880     John  0.081541  boy
# 1  1880  William  0.080511  boy
# 2  1880    James  0.050057  boy
# 3  1880  Charles  0.045167  boy
# 4  1880   George  0.043292  boy

# %%
boy_names.tail() # fungsi untuk menampilkan 5 baris terakhir
# Out:
#         year    name   percent  sex
# 128995  2008  Kolten  0.000090  boy
# 128996  2008  Damari  0.000089  boy
# 128997  2008    Hugh  0.000089  boy
# 128998  2008  Jensen  0.000089  boy
# 128999  2008   Yurem  0.000089  boy

# %% [markdown]
# Menampilkan data anak yang bernama William saja

# %%
william = names[names['name'] == 'William']
william
# Out:
#         year     name   percent   sex
# 1       1880  William  0.080511   boy
# 1001    1881  William  0.078712   boy
# 2001    1882  William  0.076191   boy
# 3001    1883  William  0.074558   boy
# 4001    1884  William  0.072475   boy
# ...      ...      ...       ...   ...
# 232825  1983  William  0.000104  girl
# 233929  1984  William  0.000088  girl
# 234878  1985  William  0.000099  girl
# 235953  1986  William  0.000090  girl
# 236957  1987  William  0.000090  girl
#
# [237 rows x 4 columns]

# %%
william.head()
# Out:
#       year     name   percent  sex
# 1     1880  William  0.080511  boy
# 1001  1881  William  0.078712  boy
# 2001  1882  William  0.076191  boy
# 3001  1883  William  0.074558  boy
# 4001  1884  William  0.072475  boy

# %% [markdown]
# Menggunakan data year sebagai index

# %%
william = william.set_index(['year']) 
william.head()
# Out:
#          name   percent  sex
# year
# 1880  William  0.080511  boy
# 1881  William  0.078712  boy
# 1882  William  0.076191  boy
# 1883  William  0.074558  boy
# 1884  William  0.072475  boy

# %% [markdown]
# Membuat plot sederhana dari data di atas

# %%
import matplotlib.pyplot as plt
from pylab import plot 
william.plot(color='Red') 
plt.show()
